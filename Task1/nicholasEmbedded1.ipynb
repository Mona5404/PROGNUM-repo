# %% [markdown]
# Answers for Week 1: The local computing environment
#
# * Name: Nicholas Ian Stephen
# * Username: nicholas
# * Student number: s6089003
# * Group (AS1, etc.): AS3

# %%
x=22/7
print(x)

# %% [markdown]
# $$y = \frac{sin(x)}{x}$$

# %%
pi=22/7 #Processed on Jupyter Hub
print(pi)

# %% [markdown]
# 1. At the end of the academic year
# 2. It is under weekly tasks in the website www.astro.rug.nl
# 3. vogelaar@astro.rug.nl
# 4. Grades and markers for all tasks
# 5. AS3
# 6. Bartosz Strent, bstrent@astro.rug.nl
# 7. Monday 15-18, Wednesday 11-14, Thursday 14-17

# %%
#Q1.4
a=6
a *= 5
a *= 4
a *= 3
a *= 2
print (a)

# %%
#Q1.5
from scipy.constants import h,c
#Importing these constants for ease of use
f=(2.42e28)
wl=c/f
#wl is in this case wavelength
E=h*(c/wl)
print(E)

# %%
#Q1.6
#Finding the force
#defining variables
M_moon=7.342e22
M_earth=5.9722e24
r=385000.6
#given in kg, and km, 
from scipy.constants import G
#G is given in m^3 kg^-1 s^-2, convert r to m for ease 
r *= 1000
#squaring the distance r preemptively
r **= 2
#defining F as the force, calculate F
F=(G*((M_moon*M_earth)/r))
print(F)

# %% [markdown]
# Q1.8
# 1. The output is /bin/bash. This shows the value of the SHELL environment variable
# 2. The output of ls is "Desktop  Documents  Downloads  Music  Pictures  Public  Task1.ipynb  Templates  Videos". This lists information about the files (by default, the current directory)
# 3. The difference between ls and ls -rtl is that there is more information given with the optional -rtl added, such as the time and date last accessed, the user it belongs to, etc.
# 4. By typing less filename.txt, where filename is replaced by the name of the file you would like to know exists, if it does exist it will show the contents of the file page by page, if not it will return "No such file or directory". Alternatively, you can access the file manager application; in this case dolphin, opening it to see if the files exist.
# 5. It copies (the contents of) the file a.txt to a new file b.txt
# 6. It moves (the contents of) the file b.txt to a new file c.txt, and deletes the old file b.txt. In essence, it renames the file.
# 7. It makes a new directory named PROGNUM
# 8. It prints the previously used directory and changes to it, in this case the directory PROGNUM
# 9. Done, using ```mkdir ./Task1```
# 10. It copies a.txt into the Task1 directory. The end dot runs a shell script in the current environment and then returns, rather than running it in a child shell.
# 11. The result is "a.txt  c.txt  Desktop  Documents  Downloads  Music  Pictures  PROGNUM  Public  Task1.ipynb  Templates  Videos", showing _all_ directories as the cd command changed from the Task1 directory to the Home directory.
# 12. You can check that it is removed either by accessing the dolphin file manager and checking where it should have been to see if it is there, or using the less a.txt command to see if it returns "No such file or directory"

# %% [markdown]
# Q1.9
#
# ![Task1-1.png](attachment:f473f952-412f-4340-a7c2-38924672ba86.png "Q1.9")

# %% [markdown]
# Q1.10
#
# ![Task1-2.png](attachment:b31028eb-d68c-4ea8-b1d9-5fe7db6a01f9.png "Q1.10")

# %% [markdown]
# Q1.11
#
# ![Task1-3.png](attachment:5b2d3563-7f56-4b82-84bd-aeca48e04a6f.png)

# %% [markdown]
# Q1.12
# 1. American Standard Code for Information Interchange
# 2. You can use kate or geany

# %% [markdown]
# Q1.13
# 1. Uniform Resource Locator
# 2. Yes, it is secure if the URL begins with http**s**, rather than just http

# %% [markdown]
# Q1.14
#
# 2. Create a ASCII file named .forward. In this file, write \username, email1@gmail.com, email2@gmail.com, etc for however many emails you would like it forwarded to.

# %% [markdown]
# Q1.15
# 1. Phishing is an attempt to obtain personal and/or private information by mail. It is done usually by attempting to make you open and log into a fake (although often convincing) version of the website you believe is the correct one, or by making you download a file (often .zip) that contains malware of sorts. It can compromise personal information, or even a system, and in doubt of a mail recieved it is always advised to check with others or administrators/IT help of the organisation, such as computergroup@astro.rug.nl. Red flags are a sense of urgency or threat of negative consequences, bad spelling or grammar mistakes, links to suspicious files, websites, URLs, requests for payments, offering of free money or things, unusual email addresses, account detail confirmations, etc.

# %% [markdown]
# Q1.16
# 1. cp -r (file/directory name)

# %% [markdown]
# Q1.17
#
# ![Task1-4.png](attachment:d5000e22-8306-47c5-9b72-56f8bbe166ad.png)

# %% [markdown]
# Q1.18
# 1. The command pwd would output /Users/users/localuser3/Downloads
# 2. . refers to the Downloads directory, and .. would refer to the localuser3 directory

# %% [markdown]
# Q1.19
# 1. The quickest way to change to this directory would be cd ./Desktop

# %% [markdown]
# Q1.21
# 3. From the command ```file```, it is output that it is ASCII text, thus not binary.

# %% [markdown]
# Q1.22
# 0. The wildcard * is used as a placeholder for matching one or more occurances for any characters, including 0 characters (not including slash and the first dot of a hidden file) when searching files.
# 1. That command outputs any files whose beginning has any number (or numbers) from 0-9, and that ends with either the c or o letters, however this is only allowed to have one letter in order to be listed.
# 2. The square brackets are used to indicate a list or a range of things (depending on what is written in between them) that is to replace the position it is in. Asterisks (*) indicate any number of those items (one or more) can replace it (in any order), while their absence indicates that it is only to be replaced with 1; files with 2 or more will not be included, e.g. in the list.
# 3. The first command indicates that after the full stop (.), that section is to be replaced with c or o **only** (thus only 1 letter), while the second command indicates that after the full stop it must contain co, no fewer letters and no different order. a command of .* [co] * (without the spaces) would indicate that it can contain any amount of instances of c and/or o, in any order.

# %% [markdown]
# Q1.23
# 1. After pressing tab, it either completes the file name for you, or if there are still multiple possibilities which it could complete with, then it lists those files beginning with what has been typed.
# 2. Just pressing the arrow keys allows you to automatically type a command you have used before, allowing you to run it again as is or after editing sections of it. Typing ls, or any part of a command before using the arrow keys will skip any that do not contain what you have typed.

# %% [markdown]
# Q1.25
# 1.
#
# ![Task1-6.png](attachment:8710cffe-8e35-463c-9370-4914a8b65550.png)
#
# 2. You should use the bulk disc for either large files or datasets and/or things you would need access to on multiple computers within Kapteyn
#
# 4 .
#
# ![Task1-7.png](attachment:c5e3090f-406b-4101-9fee-8a4263e6effb.png)

# %% [markdown]
# Q1.26
# 1. The numbers display how much space is used, what the quota (allowed amount) is and what the absolute limit (absolute maximum where it wont allow any surpassing of) is.
# 2. -s shows it in readable units for humans, e.g. MB rather than pure bytes.

# %% [markdown]
# Q1.27
# 1. The largest file is named ib_logfile0, and is taking 64.0MiB (Mebibytes)

# %% [markdown]
# Q1.28
# 1. r means readable, w means writable and x means executable
# 2. It is readable and writable for me, and only readable to both group and others
# 3. In order to change it such that it is only readable and writable to the user, you use 2 lines; chmod g-rwx filename (to remove read, write and exec permissions from the group), and chmod o-rwx filename (the same, but for others). If user doesn't have permissions to read or wite, add another line chmod u+rw filename
# 4. No, permission is denied when attempting it
# 5. No, permission is denied when attempting it
# 6. Yes, you can on virgo01

# %% [markdown]
# 1.29
# 1. The command composed is "find . -name '*.py'"

# %% [markdown]
# 1.30
# 1. The command is grep -ir task .
#
# The output is
# ![Task1-8.png](attachment:e2aa8ffb-ac4d-4679-8c1b-8fb240d13861.png)

# %% [markdown]
# 1.31
# 1. Because the file ls.out is created in order to store the output of the ls, thus that file becomes a part of the ls command's output

# %% [markdown]
# 1.32
# 1. The command ps -ef | grep username shows the currently running processes of that user, the time from when it started running, the PID, etc. The PID (2nd column) can be used to stop a process alongside the kill command.

# %% [markdown]
# 1.33
# 1. It would be possible as they are connected, however it would go through firewalls and switches to access virgo01 from the laptop zone.

# %% [markdown]
# 1.35
# 1.
#
# ![Task1-9.png](attachment:22e633fa-e03f-4f6e-a1d4-da7e2220ba19.png)

# %%
#Q1.36
x1 = 10
x2 = 22/7
print(x1, end="")
print(x2, end="")

# %% [markdown]
# Q1.36
# 1. The first 2 lines of code set the variables; x1 being set as 10 (i.e., if you put in your code x1 it will be replaced by 10), and x2 as 22/7. Then, printing the two in sequence adds the two strings together (i.e. prints them one after the other in sequence). The end=" " line should add a space after both numbers, but doesn't in the jupyter notebook for whatever reason.
