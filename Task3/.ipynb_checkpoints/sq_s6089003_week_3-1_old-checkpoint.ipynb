# %% [markdown]
# * Name: Nicholas Ian Stephen
# * Username: nicholas
# * Student s-number: s6089003
# * Group (AS1, etc.): AS5

# %%
#Session quiz 3.1

#Masses list
masses = [1.9891e+30, 1.8986e+27, 
          5.6846e+26, 1.0243e+26, 8.6810e+25,
          5.9736e+24, 4.8685e+24, 6.4185e+23, 
          3.3022e+23, 7.349e+22, 1.25e+22]
moon = 7.349e+22

print(f"Lain")
planets = []

#Check if mass is smaller than or equal to moon, then remove
    for num in masses:
        if num < moon:
            masses.remove(num)
        else:
            masses.append(num)
            
print(planets)
